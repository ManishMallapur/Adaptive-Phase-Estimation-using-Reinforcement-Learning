# %%
import strawberryfields as sf
from strawberryfields import ops
import matplotlib.pyplot as plt
from scipy.stats import poisson
import pennylane as qml
from pennylane import numpy as np

np.random.seed(0)

import numpy as np
import random
import math

from copy import deepcopy

# %%
#Select a value for the phase to be estimmated.
theta = np.pi/2

# %%
#Simulating the physical experiment.
prog = sf.Program(2)
phi = prog.params('phi')
alphap = prog.params('alpha')
thetaa = prog.params('theta')
with prog.context as q:
    ops.Dgate(alphap) | q[0]
    ops.Fock(0) | q[1]
    ops.BSgate() | (q[0],q[1])
    ops.Rgate(thetaa) | q[0]
    ops.Rgate(phi) | q[1]
    ops.BSgate() | (q[0],q[1])
    ops.MeasureFock() | [0, 1]
    

eng = sf.Engine('fock', backend_options={'cutoff_dim': 5})
cond = True
result = None
while cond:
    result = eng.run(prog, args={'phi': np.pi/4,'alpha': np.sqrt(10),'theta':theta})
    if(result.samples[0][0]+result.samples[0][1]!=0):
        break
print("Output Fock states:", result.samples)
# Out:
# Output Fock states: [[0 4]]

# %%
#Defining the Cost Function
ss = 10
def cost_function(phi,alpha):
    cost_sum = 0
    for i in range(ss):
        cond = True
        output = None
        while cond:
            output = eng.run(prog, args={'phi': phi,'alpha': alpha,'theta':np.pi/2})
            if(output.samples[0][0]+output.samples[0][1]!=0):
                break
        ket_i = output.samples[0]/np.sqrt(((output.samples[0][0])**2)+((output.samples[0][1])**2))
        target_state = [0,1]
    
        cost_sum = cost_sum + np.abs(np.dot(ket_i,target_state) - 1)
    cost = cost_sum/ss
    return cost

# %%
#Initialise the Q Table
d =100
Q_table_global = np.zeros([d,3])

# %%
#Defining the hyperparameters
n_episodes = 200
max_iter_episode = 50
exploration_proba = 0.1
exploration_decreasing_decay = 0.01
min_exploration_proba = 0.01
gamma = 0.4
lr = 0.1
action_space = [-1, 0, 1]

# %%
#defining a function to calculate variance:
def var_ftn(lst):
    s = 0+0j
    vh = 0
    p_list_pre = np.zeros(d)
    p_list = np.zeros(d)
    for i in range(len(lst)):
        p_list_pre[lst[i]] = p_list_pre[lst[i]]+1
    p_list = p_list_pre/len(lst)
    for j in range(len(p_list)):
        s = s+p_list[j]*np.exp(1j*(((j)*2*np.pi/d)-theta))
    abs_s = np.abs(s)
    vh = (abs_s)**(-2)-1
    return vh

# %%
#Choose mean number of photons in the poisson distribution
N=4

# %%
#Implementing the Q Learning Algorithm
rewards_per_episode = list()
q_table_consolidated = list()
for l in range(N,N+1):
    alph = np.sqrt(l)
    for e in range(n_episodes):
        current_state = random.randint(0, 99)
        total_episode_reward = 0
        prev_cost = 0
        for i in range(max_iter_episode): 
            if np.random.uniform(0,1) < exploration_proba:
                action = action_space[random.choice([0,1,2])]
            else:
                action = action_space[np.argmax(Q_table_global[current_state][:])]
            next_state = current_state+action
            if(next_state <= -1):
                next_state = d-1
            if(next_state >= d):
                next_state = 0
            reward = 1000*(1 - cost_function(next_state*2*np.pi/d,alph))
            Q_table_global[current_state][action_space.index(action)] = (1-lr) * Q_table_global[current_state][action_space.index(action)] +lr*(reward + gamma*max(Q_table_global[next_state][:]))
            total_episode_reward = total_episode_reward + reward
            current_state = next_state
        print("Episode done, Episode number: ",e)
        exploration_proba = max(min_exploration_proba, np.exp(-exploration_decreasing_decay*e))
# Episode done, Episode number:  113
# Episode done, Episode number:  114
# Episode done, Episode number:  115
# Episode done, Episode number:  116
# Episode done, Episode number:  117
# Episode done, Episode number:  118
# Episode done, Episode number:  119
# Episode done, Episode number:  120
# Episode done, Episode number:  121
# Episode done, Episode number:  122
# Episode done, Episode number:  123
# Episode done, Episode number:  124
# Episode done, Episode number:  125
# Episode done, Episode number:  126
# Episode done, Episode number:  127
# Episode done, Episode number:  128
# Episode done, Episode number:  129
# Episode done, Episode number:  130
# Episode done, Episode number:  131
# Episode done, Episode number:  132
# Episode done, Episode number:  133
# Episode done, Episode number:  134
# Episode done, Episode number:  135
# Episode done, Episode number:  136
# Episode done, Episode number:  137
# Episode done, Episode number:  138
# Episode done, Episode number:  139
# Episode done, Episode number:  140
# Episode done, Episode number:  141
# Episode done, Episode number:  142
# Episode done, Episode number:  143
# Episode done, Episode number:  144
# Episode done, Episode number:  145
# Episode done, Episode number:  146
# Episode done, Episode number:  147
# Episode done, Episode number:  148
# Episode done, Episode number:  149
# Episode done, Episode number:  150
# Episode done, Episode number:  151
# Episode done, Episode number:  152
# Episode done, Episode number:  153
# Episode done, Episode number:  154
# Episode done, Episode number:  155
# Episode done, Episode number:  156
# Episode done, Episode number:  157
# Episode done, Episode number:  158
# Episode done, Episode number:  159
# Episode done, Episode number:  160
# Episode done, Episode number:  161
# Episode done, Episode number:  162
# Episode done, Episode number:  163
# Episode done, Episode number:  164
# Episode done, Episode number:  165
# Episode done, Episode number:  166
# Episode done, Episode number:  167
# Episode done, Episode number:  168
# Episode done, Episode number:  169
# Episode done, Episode number:  170
# Episode done, Episode number:  171
# Episode done, Episode number:  172
# Episode done, Episode number:  173
# Episode done, Episode number:  174
# Episode done, Episode number:  175
# Episode done, Episode number:  176
# Episode done, Episode number:  177
# Episode done, Episode number:  178
# Episode done, Episode number:  179
# Episode done, Episode number:  180
# Episode done, Episode number:  181
# Episode done, Episode number:  182
# Episode done, Episode number:  183
# Episode done, Episode number:  184
# Episode done, Episode number:  185
# Episode done, Episode number:  186
# Episode done, Episode number:  187
# Episode done, Episode number:  188
# Episode done, Episode number:  189
# Episode done, Episode number:  190
# Episode done, Episode number:  191
# Episode done, Episode number:  192
# Episode done, Episode number:  193
# Episode done, Episode number:  194
# Episode done, Episode number:  195
# Episode done, Episode number:  196
# Episode done, Episode number:  197
# Episode done, Episode number:  198
# Episode done, Episode number:  199

# %%
#Calculating the Variance
act_0 = np.zeros([n_episodes,d])
phase_estimate_list_index = list()
for i in range(len(q_table_consolidated)):
    for j in range(len(q_table_consolidated[i])):
        act_0[i][j] = q_table_consolidated[i][j][1]
for i in range(len(act_0)):
    phase_estimate_list_index.append(np.argmax(act_0[i]))
import math
count = 0
s_list = list()
s_abs_list = list()
vh_list = list()
p_list_pre = np.zeros(100)
p_list = np.zeros(100)
for i in range(len(phase_estimate_list_index)):
    count = count+1
    p_list_pre[phase_estimate_list_index[i]] = p_list_pre[phase_estimate_list_index[i]]+1
    p_list = p_list_pre/count
    s = 0+0j
    for j in range(len(p_list)):
        s = s+p_list[j]*np.exp(1j*(((j)*2*np.pi/d)-theta))
    abs_s = np.abs(s)
    vh = (abs_s)**(-2)-1
    s_list.append(s)
    s_abs_list.append(abs_s)
    vh_list.append(vh)
diff_list = list()
for i in range(len(vh_list)):
    diff_list.append(vh_list[i]-(1/np.sqrt(4)))
    if(diff_list[i] < 0):
        diff_list[i] = 10000
print(vh_list[np.argmin(diff_list)])
# Out:
# 0.5014966221522683

# %%
print(1/np.sqrt(4))
# Out:
# 0.5

# %%
print(Q_table_global)
# Out:
# [[6.52586294e+02 9.98525254e+02 6.46481253e+02]
#  [7.45942934e+02 2.86858106e+02 4.10541267e+02]
#  [2.67071781e+02 2.35015166e+02 4.80610203e+02]
#  [2.41666040e+02 6.44550351e+01 4.31040737e+02]
#  [6.81698458e+01 7.13981384e+01 5.98591173e+02]
#  [1.61334037e+02 3.29959139e+02 1.06228481e+03]
#  [6.93925338e+02 8.61592360e+02 1.33877830e+03]
#  [1.28963669e+03 1.33057712e+03 1.37764544e+03]
#  [1.36169718e+03 1.05702700e+03 7.67364296e+02]
#  [1.17293583e+03 1.36465161e+03 9.82811045e+02]
#  [1.30809568e+03 1.44459927e+03 1.29012093e+03]
#  [1.41566522e+03 6.15216373e+02 5.29856388e+02]
#  [1.18473095e+03 3.31156190e+02 2.76994669e+02]
#  [9.39957928e+02 9.28481555e+01 3.92212758e+02]
#  [8.85908779e+02 5.39357829e+02 6.13198495e+02]
#  [9.32013453e+02 8.29189595e+02 1.57704109e+03]
#  [1.55638153e+03 1.59938736e+03 1.61363282e+03]
#  [1.62689286e+03 1.52136406e+03 1.51876420e+03]
#  [1.58910547e+03 5.91063704e+02 1.13535816e+03]
#  [1.39736983e+03 1.63369465e+03 1.31889464e+03]
#  [1.53247029e+03 7.29413200e+02 1.06038801e+03]
#  [1.26218175e+03 1.64313095e+03 1.33528373e+03]
#  [1.53250509e+03 4.54747079e+02 7.81184216e+02]
#  [1.03629838e+03 1.52577619e+03 6.51399900e+02]
#  [9.64189338e+02 6.11385872e+02 1.51259448e+03]
#  [1.51808151e+03 3.76850223e+02 5.78380735e+02]
#  [5.17809528e+02 2.45546754e+02 1.11206717e+03]
#  [1.07488217e+03 3.11080286e+02 4.91226552e+02]
#  [1.00000000e+02 5.49441886e+02 9.77622487e+02]
#  [6.19937934e+02 2.39235221e+02 1.33415288e+03]
#  [1.01375018e+03 1.02242678e+03 1.61648314e+03]
#  [1.60853064e+03 1.64402248e+03 1.57819622e+03]
#  [1.61557079e+03 1.22376873e+03 1.14934629e+03]
#  [1.36061356e+03 6.58402256e+02 7.13398537e+02]
#  [1.03472384e+03 2.79659148e+02 9.03568681e+01]
#  [4.06694608e+02 0.00000000e+00 2.02821160e+02]
#  [2.65995924e+02 4.36153999e+02 7.37910638e+02]
#  [6.77482808e+02 5.44486586e+02 1.34817079e+03]
#  [1.22297152e+03 1.20348220e+03 1.50551327e+03]
#  [1.52205897e+03 1.28400661e+03 1.08661211e+03]
#  [1.35936544e+03 6.16545139e+02 3.96695912e+02]
#  [8.81760418e+02 7.50566568e+02 1.39192780e+03]
#  [1.40979588e+03 8.92300006e+02 9.90647824e+02]
#  [1.22120990e+03 1.22665990e+03 1.31082869e+03]
#  [1.28834102e+03 1.30896959e+03 1.27993871e+03]
#  [1.27513624e+03 1.27107327e+03 1.15502036e+03]
#  [1.28192418e+03 8.40961166e+02 9.23105181e+02]
